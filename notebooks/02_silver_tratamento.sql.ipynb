# %% [markdown]
# Notebook: 02_silver_tratamento.sql
#
# -- Objetivo: aplicar regras de qualidade e padronização (dedupe, nulls, tipos, datas)
#
# -- Status: em construção

# %%
# %sql
SELECT current_catalog(),current_schema();
